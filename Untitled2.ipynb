# %%
import os
import pandas as pd
import json

# %%
import snscrape.modules.twitter as sntwitter
import pandas

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Ecological Footprint since:2020-01-01 until:2021-05-31').get_items()):
    if i>3000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content])
    
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Text', 'LikesCount', 'User'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\users\fruto\anaconda3\envs\dataanalytics\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# c:\users\fruto\anaconda3\envs\dataanalytics\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     692             raise AssertionError(
# --> 693                 f"{len(columns)} columns passed, passed data had "
#     694                 f"{len(content)} columns"
#
# AssertionError: 4 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
tweets_df2

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('3000_tweets.csv', sep=',', index=False)
