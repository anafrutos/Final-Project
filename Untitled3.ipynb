# %%
from jupyter_dash import JupyterDash

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.express as px
from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import io
import chart_studio
import chart_studio.plotly as cspy
username = 'anafrutos' # your username
api_key = 'TwP6MMXuuqkuqGglBoql' 
chart_studio.tools.set_credentials_file(username='anafrutos', api_key='TwP6MMXuuqkuqGglBoql')

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = "{:,.2f}".format

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
data = pd.read_excel('../dataset/nfa_year.xlsx')
data
# Out:
#       country  year        record      crop_land   grazing_land  \
# 0     Armenia  1996  BiocapTotGHA     604,606.62     538,873.18
# 1     Armenia  1996  EFConsTotGHA   1,383,480.58     708,381.32
# 2     Armenia  1997  BiocapTotGHA     476,395.51     561,572.69
# 3     Armenia  1997  EFConsTotGHA   1,227,984.94     810,583.94
# 4     Armenia  1998  BiocapTotGHA     594,089.68     562,286.11
# ...       ...   ...           ...            ...            ...
# 5280    China  2014  EFConsTotGHA 821,581,170.70 197,956,304.80
# 5281    China  2015  BiocapTotGHA 682,473,730.60 146,395,194.30
# 5282    China  2015  EFConsTotGHA 862,590,137.10 196,395,053.90
# 5283    China  2016  BiocapTotGHA 687,406,250.20 146,586,665.30
# 5284    China  2016  EFConsTotGHA 853,948,476.80 201,502,265.60
#
#         forest_land  fishing_ground  built_up_land           carbon  \
# 0        289,618.23       47,014.82     110,993.95             0.00
# ...

# %%
data['year'] = pd.to_datetime(data['year'], format='%Y')
data
# Out:
#       country       year        record      crop_land   grazing_land  \
# 0     Armenia 1996-01-01  BiocapTotGHA     604,606.62     538,873.18
# 1     Armenia 1996-01-01  EFConsTotGHA   1,383,480.58     708,381.32
# 2     Armenia 1997-01-01  BiocapTotGHA     476,395.51     561,572.69
# 3     Armenia 1997-01-01  EFConsTotGHA   1,227,984.94     810,583.94
# 4     Armenia 1998-01-01  BiocapTotGHA     594,089.68     562,286.11
# ...       ...        ...           ...            ...            ...
# 5280    China 2014-01-01  EFConsTotGHA 821,581,170.70 197,956,304.80
# 5281    China 2015-01-01  BiocapTotGHA 682,473,730.60 146,395,194.30
# 5282    China 2015-01-01  EFConsTotGHA 862,590,137.10 196,395,053.90
# 5283    China 2016-01-01  BiocapTotGHA 687,406,250.20 146,586,665.30
# 5284    China 2016-01-01  EFConsTotGHA 853,948,476.80 201,502,265.60
#
#         forest_land  fishing_ground  built_up_land           carbon  \
# 0        289,618.23       47,014.82     110,993.95             0.00
# ...

# %%
data.to_excel('../dataset/nfa_year_cleaned.xlsx',index=False)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5285 entries, 0 to 5284
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   country         5285 non-null   object
#  1   year            5285 non-null   datetime64[ns]
#  2   record          5285 non-null   object
#  3   crop_land       5285 non-null   float64
#  4   grazing_land    5285 non-null   float64
#  5   forest_land     5285 non-null   float64
#  6   fishing_ground  5285 non-null   float64
#  7   built_up_land   5285 non-null   float64
#  8   carbon          5285 non-null   float64
#  9   total           5285 non-null   float64
#  10  Continent       5285 non-null   object
# dtypes: datetime64[ns](1), float64(7), object(3)
# memory usage: 454.3+ KB
