# %% [markdown]
# # Business Case- Ecological Footprint

# %% [markdown]
# - **ECOLOGICAL DEFICIT/RESERVE: BIOCAPACITY:** An ecological deficit occurs when the Ecological Footprint of a population exceeds the biocapacity of the area available to that population. A national ecological deficit means that the nation is importing biocapacity through trade, liquidating national ecological assets or emitting carbon dioxide waste into the atmosphere. An ecological reserve exists when the biocapacity of a region exceeds its population's Ecological Footprint.
# - **ECOLOGICAL FOOTPRINT:** The Ecological Footprint measures how much demand human consumption places on the biosphere. It is measured in standard units called global hectares.
# - **ECOLOGICAL FOOTPRINT PER PERSON:** The Ecological Footprint per person is a nation's total Ecological Footprint divided by the total population of the nation. To live within the means of our planet's resources, the world's Ecological Footprint would have to equal the available biocapacity per person on our planet, which is currently 1.7 global hectares. So if a nation's Ecological Footprint per person is 6.8 global hectares, its citizens are demanding four times the resources and wastes that our planet can regenerate and absorb in the atmosphere.

# %% [markdown]
# # Business Case

# %%
#pd.options.display.max_rows=72186
#pd.set_option('display.float_format', lambda x: '%.10f' % x)


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mlt

import pycountry_convert as pc

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from pandas import set_option

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.float_format = "{:,.2f}".format

# %%
import sys
sys.path.insert(0, 'C:/Users/fruto/OneDrive/Escritorio/DATA SCIENCE COURSE/Funtions')
from MY_FUNCTION_EDA import *
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_excel('../../dataset/NFA.EFConsTotGHA.xlsx')

data
# Out:
#       country  year        record      crop_land   grazing_land  \
# 0     Armenia  1996  EFConsTotGHA   1,383,480.58     708,381.32
# 1     Armenia  1997  EFConsTotGHA   1,227,984.94     810,583.94
# 2     Armenia  1998  EFConsTotGHA   1,412,113.80     667,997.72
# 3     Armenia  1999  EFConsTotGHA   1,162,799.21     618,777.31
# 4     Armenia  2000  EFConsTotGHA   1,239,270.60     614,780.28
# ...       ...   ...           ...            ...            ...
# 2634    China  2012  EFConsTotGHA 797,851,164.40 179,303,064.10
# 2635    China  2013  EFConsTotGHA 806,576,465.60 193,878,270.80
# 2636    China  2014  EFConsTotGHA 821,581,170.70 197,956,304.80
# 2637    China  2015  EFConsTotGHA 862,590,137.10 196,395,053.90
# 2638    China  2016  EFConsTotGHA 853,948,476.80 201,502,265.60
#
#         forest_land  fishing_ground  built_up_land           carbon  \
# 0             53.01        9,740.27     110,993.95     1,059,296.79
# ...

# %%
data.isnull().sum()
# Out:
# country           0
# year              0
# record            0
# crop_land         0
# grazing_land      0
# forest_land       0
# fishing_ground    0
# built_up_land     0
# carbon            0
# total             0
# Continent         0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2634    False
# 2635    False
# 2636    False
# 2637    False
# 2638    False
# Length: 2639, dtype: bool

# %%
data.Continent.value_counts()
# Out:
# Asia             754
# Africa           714
# Europe           629
# North America    294
# South America    206
# Oceania           42
# Name: Continent, dtype: int64

# %% [markdown]
# data_clean = data.drop([1293, 2901, 3725, 3977, 9121,1205,3481, 4301,
#                                        8637, 1209, 6465, 2993, 3969, 3973, 4465, 5589, 8145, 8393], axis = 0)

# %%
Oceania = data[data.Continent == 'Oceania']
Oceania
# Out:
#        country  year        record     crop_land  grazing_land   forest_land  \
# 105  Australia  1996  EFConsTotGHA 22,241,482.89 18,532,971.63 19,261,903.25
# 106  Australia  1997  EFConsTotGHA 11,658,036.14 15,332,584.24 19,767,237.61
# 107  Australia  1998  EFConsTotGHA 20,525,816.38 20,902,264.73 21,246,635.09
# 108  Australia  1999  EFConsTotGHA 20,211,174.79 18,362,678.54 20,871,373.34
# 109  Australia  2000  EFConsTotGHA 16,074,301.69 16,742,389.27 23,702,374.59
# 110  Australia  2001  EFConsTotGHA 19,242,873.68 16,708,985.66 22,138,389.26
# 111  Australia  2002  EFConsTotGHA 24,592,798.22 22,283,460.94 21,834,045.58
# 112  Australia  2003  EFConsTotGHA  9,191,519.60 27,225,476.19 23,076,512.92
# 113  Australia  2004  EFConsTotGHA 20,711,768.53 22,778,899.91 24,006,903.94
# 114  Australia  2005  EFConsTotGHA 20,726,111.97 22,439,306.48 24,149,852.68
# 115  Australia  2006  EFConsTotGHA 25,059,334.29 19,394,083.53 23,632,962.45
# ...

# %% [markdown]
# country_mean =  EFConsTotGHA.groupby(['country','year'])['crop_land', 'grazing_land', 'forest_land', 'fishing_ground', 'built_up_land', 'carbon', 'total'].mean()
# country_mean

# %% [markdown]
# country_sorted = country_mean.sort_values(['crop_land','grazing_land', 'forest_land', 'fishing_ground', 'built_up_land', 'carbon', 'total'],ascending=False)
# #fin_ = country_sorted.head(20)
# country_sorted.tail(50)

# %% [markdown]
# ## Visualizing Data using Matplotlib

# %%
# %matplotlib inline

import matplotlib as mplt
import matplotlib.pyplot as plt

mplt.style.use('ggplot')

# %%
countries = data[data['country'].isin(['China','Singapore', 'United States of America', 'Spain'])]
countries
# Out:
#         country  year        record      crop_land   grazing_land  \
# 2031  Singapore  1996  EFConsTotGHA   1,571,360.76     745,397.93
# 2032  Singapore  1997  EFConsTotGHA   1,497,618.89     807,755.67
# 2033  Singapore  1998  EFConsTotGHA   1,043,806.08     728,424.81
# 2034  Singapore  1999  EFConsTotGHA   1,873,534.91     876,965.40
# 2035  Singapore  2000  EFConsTotGHA   1,861,015.89     918,895.96
# ...         ...   ...           ...            ...            ...
# 2634      China  2012  EFConsTotGHA 797,851,164.40 179,303,064.10
# 2635      China  2013  EFConsTotGHA 806,576,465.60 193,878,270.80
# 2636      China  2014  EFConsTotGHA 821,581,170.70 197,956,304.80
# 2637      China  2015  EFConsTotGHA 862,590,137.10 196,395,053.90
# 2638      China  2016  EFConsTotGHA 853,948,476.80 201,502,265.60
#
#         forest_land  fishing_ground  built_up_land           carbon  \
# 2031   2,369,766.75      646,313.09      24,267.39    18,242,297.93
# ...

# %%
import plotly.express as px

print(px.colors.qualitative.Antique)
# Out:
# ['rgb(133, 92, 117)', 'rgb(217, 175, 107)', 'rgb(175, 100, 88)', 'rgb(115, 111, 76)', 'rgb(82, 106, 131)', 'rgb(98, 83, 119)', 'rgb(104, 133, 92)', 'rgb(156, 156, 94)', 'rgb(160, 97, 119)', 'rgb(140, 120, 93)', 'rgb(124, 124, 124)']

# %%
countries
# Out:
#         country  year        record      crop_land   grazing_land  \
# 2031  Singapore  1996  EFConsTotGHA   1,571,360.76     745,397.93
# 2032  Singapore  1997  EFConsTotGHA   1,497,618.89     807,755.67
# 2033  Singapore  1998  EFConsTotGHA   1,043,806.08     728,424.81
# 2034  Singapore  1999  EFConsTotGHA   1,873,534.91     876,965.40
# 2035  Singapore  2000  EFConsTotGHA   1,861,015.89     918,895.96
# ...         ...   ...           ...            ...            ...
# 2634      China  2012  EFConsTotGHA 797,851,164.40 179,303,064.10
# 2635      China  2013  EFConsTotGHA 806,576,465.60 193,878,270.80
# 2636      China  2014  EFConsTotGHA 821,581,170.70 197,956,304.80
# 2637      China  2015  EFConsTotGHA 862,590,137.10 196,395,053.90
# 2638      China  2016  EFConsTotGHA 853,948,476.80 201,502,265.60
#
#         forest_land  fishing_ground  built_up_land           carbon  \
# 2031   2,369,766.75      646,313.09      24,267.39    18,242,297.93
# ...

# %%
import plotly.express as px
for template in ["plotly_dark"]:
    fig = px.line(countries, x="year", y="crop_land", color="country", line_group="country",
              line_shape="spline", render_mode="svg",
                  template=template,
             color_discrete_sequence=px.colors.qualitative.G10,
             title="Built-in G10 color sequence")

fig.show()
# Out:
# <div>
#
#
#             <div id="baae7c76-8cb3-42ac-ab08-0d35618e17db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("baae7c76-8cb3-42ac-ab08-0d35618e17db")) {
#                     Plotly.newPlot(
#                         'baae7c76-8cb3-42ac-ab08-0d35618e17db',
# ...

# %%
color_continent = ['Khaki','DarkSeaGreen','DarkCyan','Chocolate','FireBrick', 'CadetBlue']

# %%
data[data.Continent == 'Not assigned']
# Out:
# Empty DataFrame
# Columns: [country, year, record, crop_land, grazing_land, forest_land, fishing_ground, built_up_land, carbon, total, Continent]
# Index: []

# %%
import plotly.express as px
for template in ["simple_white"]:
    fig = px.area(data, x="year", y="crop_land", color="Continent",
     line_group="country", template=template,
             color_discrete_sequence=color_continent)

fig.update_layout(
    autosize=False,
    height=600,
    width=900,
    bargap=0.10,
    bargroupgap=0.1,
    barmode="stack",
    hovermode="x",
    margin=dict(r=40, l=100, b=75, t=125),)
fig.show()

for template in ["simple_white"]:
    fig = px.area(data, x="year", y="forest_land", color="Continent",
     line_group="country", template=template,
             color_discrete_sequence=color_continent)

fig.update_layout(
    autosize=False,
    height=600,
    width=900,
    bargap=0.10,
    bargroupgap=0.1,
    barmode="stack",
    hovermode="x",
    margin=dict(r=40, l=100, b=75, t=125),)
fig.show()
# Out:
# <div>
#
#
#             <div id="1b8c3509-ed15-44bc-910a-cda7e539b7ae" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1b8c3509-ed15-44bc-910a-cda7e539b7ae")) {
#                     Plotly.newPlot(
#                         '1b8c3509-ed15-44bc-910a-cda7e539b7ae',
# ...

# %%
import plotly.express as px
for template in ["simple_white"]:
    fig = px.area(data, x="year", y="forest_land", color="Continent",
     line_group="country", template=template,
             color_discrete_sequence=color_continent)

fig.update_layout(
    autosize=False,
    height=600,
    width=900,
    bargap=0.10,
    bargroupgap=0.1,
    barmode="stack",
    hovermode="x",
    margin=dict(r=50, l=100, b=85, t=125),)
fig.show()
# Out:
# <div>
#
#
#             <div id="12e895db-48c3-4ea4-9d7f-e3791826bb39" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("12e895db-48c3-4ea4-9d7f-e3791826bb39")) {
#                     Plotly.newPlot(
#                         '12e895db-48c3-4ea4-9d7f-e3791826bb39',
# ...

# %%
import plotly.express as px
for template in ["simple_white"]:
    fig = px.area(data, x="year", y="grazing_land", color="Continent",
     line_group="country", template=template,
             color_discrete_sequence=color_continent)

fig.update_layout(
    autosize=False,
    height=600,
    width=900,
    bargap=0.10,
    bargroupgap=0.1,
    barmode="stack",
    hovermode="x",
    margin=dict(r=50, l=100, b=85, t=125),)
fig.show()
# Out:
# <div>
#
#
#             <div id="595894d0-4781-40cf-ace1-2b27f73acc71" class="plotly-graph-div" style="height:600px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("595894d0-4781-40cf-ace1-2b27f73acc71")) {
#                     Plotly.newPlot(
#                         '595894d0-4781-40cf-ace1-2b27f73acc71',
# ...
